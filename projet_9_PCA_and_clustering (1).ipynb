# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
from factor_analyzer.factor_analyzer import calculate_kmo
from factor_analyzer.factor_analyzer import FactorAnalyzer

# %%
X=pd.read_csv("C:/Users/lenovo/OneDrive/Desktop/DAN-P9-data/fichier_final.csv",encoding = 'utf8')
X.head()
# Out:
#              Zone  Disponibilite_autres_viandes  Disponibilite_cereales  \
# 0     Afghanistan                         260.0                    10.0
# 1  Afrique du Sud                        1404.0                    75.0
# 2         Albanie                          89.0                     0.0
# 3         Algérie                         490.0                     8.0
# 4       Allemagne                        5475.0                  2228.0
#
#    Disponibilite_volaille  Exportations_autres_viandes  Exportations_cereales  \
# 0                    57.0                          0.0                    0.0
# 1                  2118.0                         76.0                   16.0
# 2                    47.0                          0.0                    0.0
# 3                   277.0                          0.0                    0.0
# 4                  1739.0                       2956.0                  250.0
#
#    Exportations_volaille  Importations_autres_viandes  Importations_cereales  \
# 0                    0.0                          6.0                    0.0
# 1                   63.0                         56.0                   15.0
# 2                    0.0                         12.0                    1.0
# 3                    0.0                         50.0                    8.0
# 4                  646.0                       1725.0                  416.0
#
#    Importations_volaille  ...  Pertes_cereales  Pertes_volaille  \
# 0                   29.0  ...              0.0              2.0
# 1                  514.0  ...              1.0             83.0
# 2                   38.0  ...              0.0              0.0
# 3                    2.0  ...              0.0             13.0
# 4                  842.0  ...             73.0              0.0
#
#    Production_autres_viandes  Production_cereales  Production_volaille  \
# 0                      254.0                  9.0                 28.0
# 1                     1420.0                 74.0               1667.0
# 2                       77.0                  0.0                 13.0
# 3                      440.0                  0.0                275.0
# 4                     6675.0               2360.0               1514.0
#
#    Population           PIB  Valeur_ajoutee_agriculture  Sous_alimentation  \
# 0   36296.113  1.889635e+04                 4992.453824               22.7
# 1   57009.756  3.808514e+05                 9497.680787                5.7
# 2    2884.169  1.301973e+04                 2476.629502                4.2
# 3   41389.189  1.700970e+05                19996.432170                2.6
# 4   82658.409  3.690849e+06                31436.767780                0.0
#
#    Stabilite_politique
# 0                -2.80
# 1                -0.28
# 2                 0.38
# 3                -0.92
# 4                 0.59
#
# [5 rows x 24 columns]

# %%
X.set_index('Zone', inplace=True)

# %%
sc = StandardScaler()
Z = pd.DataFrame(sc.fit_transform(X), columns=X.columns,index=X.index)
Z
# Out:
#                        Disponibilite_autres_viandes  Disponibilite_cereales  \
# Zone
# Afghanistan                               -0.247363               -0.259565
# Afrique du Sud                             0.295132               -0.206160
# Albanie                                   -0.328452               -0.267781
# Algérie                                   -0.138295               -0.261208
# Allemagne                                  2.225634                1.562770
# ...                                             ...                     ...
# Émirats arabes unis                       -0.262537               -0.248062
# Équateur                                  -0.154418               -0.266138
# États-Unis d'Amérique                     10.021147                0.249013
# Éthiopie                                  -0.148253                4.705434
# Îles Salomon                              -0.368286               -0.267781
#
#                        Disponibilite_volaille  Exportations_autres_viandes  \
# Zone
# Afghanistan                         -0.305390                    -0.320493
# Afrique du Sud                       0.881014                    -0.181365
# Albanie                             -0.311146                    -0.320493
# Algérie                             -0.178748                    -0.320493
# Allemagne                            0.662845                     5.090853
# ...                                       ...                          ...
# Émirats arabes unis                 -0.101036                    -0.287541
# Équateur                            -0.141907                    -0.320493
# États-Unis d'Amérique               10.176527                     6.791510
# Éthiopie                            -0.330143                    -0.320493
# Îles Salomon                        -0.336475                    -0.320493
#
#                        Exportations_cereales  Exportations_volaille  \
# Zone
# Afghanistan                        -0.334395              -0.211267
# Afrique du Sud                     -0.108632              -0.071809
# Albanie                            -0.334395              -0.211267
# Algérie                            -0.334395              -0.211267
# Allemagne                           3.193156               1.218730
# ...                                      ...                    ...
# Émirats arabes unis                -0.221513              -0.003187
# Équateur                           -0.306174              -0.211267
# États-Unis d'Amérique               4.011548               7.961413
# Éthiopie                           -0.249734              -0.211267
# Îles Salomon                       -0.334395              -0.211267
#
#                        Importations_autres_viandes  Importations_cereales  \
# Zone
# Afghanistan                              -0.390161              -0.354417
# Afrique du Sud                           -0.253741              -0.061326
# Albanie                                  -0.373791              -0.334878
# Algérie                                  -0.270112              -0.198102
# Allemagne                                 4.299957               7.773994
# ...                                            ...                    ...
# Émirats arabes unis                       0.076395               0.251306
# Équateur                                 -0.403803              -0.334878
# États-Unis d'Amérique                     5.604132               6.425772
# Éthiopie                                 -0.403803              -0.295799
# Îles Salomon                             -0.403803              -0.354417
#
#                        Importations_volaille  Nourriture_autres_viandes  ...  \
# Zone                                                                     ...
# Afghanistan                        -0.303025                  -0.245818  ...
# Afrique du Sud                      2.366765                   0.278034  ...
# Albanie                            -0.253482                  -0.320450  ...
# Algérie                            -0.451652                  -0.139811  ...
# Allemagne                           4.172314                   2.237484  ...
# ...                                      ...                        ...  ...
# Émirats arabes unis                 1.920883                  -0.291453  ...
# Équateur                           -0.462662                  -0.156449  ...
# États-Unis d'Amérique               0.214419                  10.085743  ...
# Éthiopie                           -0.457157                  -0.150745  ...
# Îles Salomon                       -0.429634                  -0.360380  ...
#
#                        Pertes_cereales  Pertes_volaille  \
# Zone
# Afghanistan                  -0.283615        -0.187824
# Afrique du Sud               -0.268574         1.110627
# Albanie                      -0.283615        -0.219885
# Algérie                      -0.283615        -0.011492
# Allemagne                     0.814420        -0.219885
# ...                                ...              ...
# Émirats arabes unis          -0.283615        -0.219885
# Équateur                     -0.283615         0.052629
# États-Unis d'Amérique         0.062341        -0.219885
# Éthiopie                      4.785397        -0.203855
# Îles Salomon                 -0.283615        -0.219885
#
#                        Production_autres_viandes  Production_cereales  \
# Zone
# Afghanistan                            -0.240439            -0.258203
# Afrique du Sud                          0.265776            -0.207277
# Albanie                                -0.317283            -0.265254
# Algérie                                -0.159687            -0.265254
# Allemagne                               2.547215             1.583753
# ...                                          ...                  ...
# Émirats arabes unis                    -0.317283            -0.265254
# Équateur                               -0.158385            -0.264471
# États-Unis d'Amérique                   9.892973             0.244006
# Éthiopie                               -0.147965             4.667521
# Îles Salomon                           -0.349409            -0.265254
#
#                        Production_volaille  Population        PIB  \
# Zone
# Afghanistan                      -0.277933    0.006401  -0.235154
# Afrique du Sud                    0.500105    0.190928  -0.012689
# Albanie                          -0.285053   -0.291250  -0.238766
# Algérie                          -0.160681    0.051772  -0.142223
# Allemagne                         0.427476    0.419419   2.021702
# ...                                    ...         ...        ...
# Émirats arabes unis              -0.268439   -0.232427  -0.009767
# Équateur                         -0.129826   -0.167411  -0.182666
# États-Unis d'Amérique            10.111419    2.579077  11.724395
# Éthiopie                         -0.284579    0.630921  -0.199568
# Îles Salomon                     -0.291225   -0.311278  -0.245865
#
#                        Valeur_ajoutee_agriculture  Sous_alimentation  \
# Zone
# Afghanistan                             -0.230323           1.272932
# Afrique du Sud                          -0.116732          -0.272306
# Albanie                                 -0.293755          -0.408650
# Algérie                                  0.147976          -0.554084
# Allemagne                                0.436424          -0.790415
# ...                                           ...                ...
# Émirats arabes unis                     -0.281285          -0.399561
# Équateur                                -0.110873           0.191266
# États-Unis d'Amérique                    4.066205          -0.790415
# Éthiopie                                 0.297849           0.618479
# Îles Salomon                            -0.343866           1.045691
#
#                        Stabilite_politique
# Zone
# Afghanistan                      -3.042060
# Afrique du Sud                   -0.218804
# Albanie                           0.520621
# Algérie                          -0.935821
# Allemagne                         0.755892
# ...                                    ...
# Émirats arabes unis               0.789502
# Équateur                          0.016468
# États-Unis d'Amérique             0.419790
# Éthiopie                         -1.787279
# Îles Salomon                      0.318959
#
# [166 rows x 23 columns]

# %%
kmo_all,kmo_model=calculate_kmo(Z)
kmo_model
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# 0.7020877133305805

# %% [markdown]
# ### KMO selon la charte quie est moyen

# %%
n_comp=3
fa = FactorAnalyzer(rotation = 'varimax',impute = "drop",n_factors=n_comp)
coord=fa.fit_transform(Z)

results=pd.DataFrame(fa.get_communalities(),columns=['communalities'])
results=results.join(pd.DataFrame(fa.loadings_))
results['components']=results.index+1
results['eigen_values']=fa.get_eigenvalues()[0]
results['variance_%']=list(fa.get_factor_variance()[1])+[None]*(results.shape[0]-n_comp)
results['cumulative_variance_%']=list(fa.get_factor_variance()[2])+[None]*(results.shape[0]-n_comp)

results.index=Z.columns
results
# Out:
#                               communalities         0         1         2  \
# Disponibilite_autres_viandes       0.972667  0.933379  0.109597  0.299097
# Disponibilite_cereales             0.842006 -0.000387  0.892320  0.213941
# Disponibilite_volaille             0.978812  0.972844  0.140406  0.112568
# Exportations_autres_viandes        0.697567  0.661591  0.197390  0.470002
# Exportations_cereales              0.430959  0.322379  0.244207  0.517101
# Exportations_volaille              0.714606  0.830191 -0.006154  0.159217
# Importations_autres_viandes        0.717734  0.466497  0.042731  0.705895
# Importations_cereales              0.664158  0.496761  0.050519  0.644076
# Importations_volaille              0.242878  0.146867  0.009737  0.470333
# Nourriture_autres_viandes          0.972068  0.934439  0.086428  0.302360
# Nourriture_cereales                0.912500  0.002341  0.946132 -0.131639
# Nourriture_volaille                0.979701  0.976413  0.109918  0.119313
# Pertes_autres_viandes              0.627345  0.125756  0.780281 -0.051886
# Pertes_cereales                    0.644963 -0.032547  0.795235  0.107259
# Pertes_volaille                    0.649190  0.107996  0.785829 -0.141420
# Production_autres_viandes          0.975103  0.941140  0.136381  0.266004
# Production_cereales                0.855146  0.000277  0.899872  0.213019
# Production_volaille                0.983345  0.982339  0.108976  0.080493
# Population                         0.892601  0.350782  0.868440 -0.123960
# PIB                                0.818859  0.830920  0.102111  0.343517
# Valeur_ajoutee_agriculture         0.874167  0.479421  0.799770 -0.068491
# Sous_alimentation                  0.126296 -0.107704  0.022071 -0.337948
# Stabilite_politique                0.140480 -0.048248 -0.185366  0.322167
#
#                               components  eigen_values  variance_%  \
# Disponibilite_autres_viandes           1     10.307390    0.360762
# Disponibilite_cereales                 2      5.364660    0.260169
# Disponibilite_volaille                 3      1.838921    0.105728
# Exportations_autres_viandes            4      1.338770         NaN
# Exportations_cereales                  5      1.157145         NaN
# Exportations_volaille                  6      0.734731         NaN
# Importations_autres_viandes            7      0.558536         NaN
# Importations_cereales                  8      0.456665         NaN
# Importations_volaille                  9      0.397039         NaN
# Nourriture_autres_viandes             10      0.202747         NaN
# Nourriture_cereales                   11      0.163843         NaN
# Nourriture_volaille                   12      0.152073         NaN
# Pertes_autres_viandes                 13      0.096721         NaN
# Pertes_cereales                       14      0.090770         NaN
# Pertes_volaille                       15      0.066116         NaN
# Production_autres_viandes             16      0.035702         NaN
# Production_cereales                   17      0.028815         NaN
# Production_volaille                   18      0.008166         NaN
# Population                            19      0.000543         NaN
# PIB                                   20      0.000281         NaN
# Valeur_ajoutee_agriculture            21      0.000189         NaN
# Sous_alimentation                     22      0.000124         NaN
# Stabilite_politique                   23      0.000053         NaN
#
#                               cumulative_variance_%
# Disponibilite_autres_viandes               0.360762
# Disponibilite_cereales                     0.620931
# Disponibilite_volaille                     0.726659
# Exportations_autres_viandes                     NaN
# Exportations_cereales                           NaN
# Exportations_volaille                           NaN
# Importations_autres_viandes                     NaN
# Importations_cereales                           NaN
# Importations_volaille                           NaN
# Nourriture_autres_viandes                       NaN
# Nourriture_cereales                             NaN
# Nourriture_volaille                             NaN
# Pertes_autres_viandes                           NaN
# Pertes_cereales                                 NaN
# Pertes_volaille                                 NaN
# Production_autres_viandes                       NaN
# Production_cereales                             NaN
# Production_volaille                             NaN
# Population                                      NaN
# PIB                                             NaN
# Valeur_ajoutee_agriculture                      NaN
# Sous_alimentation                               NaN
# Stabilite_politique                             NaN

# %% [markdown]
# ### communalities : on supprime les variables qui sont expliquee a moins de 30%

# %%
Z.drop(columns=['Sous_alimentation','Stabilite_politique','Importations_volaille'],inplace=True)
Z.head()
# Out:
#                 Disponibilite_autres_viandes  Disponibilite_cereales  \
# Zone
# Afghanistan                        -0.247363               -0.259565
# Afrique du Sud                      0.295132               -0.206160
# Albanie                            -0.328452               -0.267781
# Algérie                            -0.138295               -0.261208
# Allemagne                           2.225634                1.562770
#
#                 Disponibilite_volaille  Exportations_autres_viandes  \
# Zone
# Afghanistan                  -0.305390                    -0.320493
# Afrique du Sud                0.881014                    -0.181365
# Albanie                      -0.311146                    -0.320493
# Algérie                      -0.178748                    -0.320493
# Allemagne                     0.662845                     5.090853
#
#                 Exportations_cereales  Exportations_volaille  \
# Zone
# Afghanistan                 -0.334395              -0.211267
# Afrique du Sud              -0.108632              -0.071809
# Albanie                     -0.334395              -0.211267
# Algérie                     -0.334395              -0.211267
# Allemagne                    3.193156               1.218730
#
#                 Importations_autres_viandes  Importations_cereales  \
# Zone
# Afghanistan                       -0.390161              -0.354417
# Afrique du Sud                    -0.253741              -0.061326
# Albanie                           -0.373791              -0.334878
# Algérie                           -0.270112              -0.198102
# Allemagne                          4.299957               7.773994
#
#                 Nourriture_autres_viandes  Nourriture_cereales  \
# Zone
# Afghanistan                     -0.245818            -0.168478
# Afrique du Sud                   0.278034            -0.114522
# Albanie                         -0.320450            -0.178810
# Algérie                         -0.139811            -0.175366
# Allemagne                        2.237484            -0.155850
#
#                 Nourriture_volaille  Pertes_autres_viandes  Pertes_cereales  \
# Zone
# Afghanistan               -0.295561              -0.054960        -0.283615
# Afrique du Sud             0.862665               0.829445        -0.268574
# Albanie                   -0.300241              -0.272182        -0.283615
# Algérie                   -0.173304               0.069167        -0.283615
# Allemagne                  0.613471              -0.194603         0.814420
#
#                 Pertes_volaille  Production_autres_viandes  \
# Zone
# Afghanistan           -0.187824                  -0.240439
# Afrique du Sud         1.110627                   0.265776
# Albanie               -0.219885                  -0.317283
# Algérie               -0.011492                  -0.159687
# Allemagne             -0.219885                   2.547215
#
#                 Production_cereales  Production_volaille  Population  \
# Zone
# Afghanistan               -0.258203            -0.277933    0.006401
# Afrique du Sud            -0.207277             0.500105    0.190928
# Albanie                   -0.265254            -0.285053   -0.291250
# Algérie                   -0.265254            -0.160681    0.051772
# Allemagne                  1.583753             0.427476    0.419419
#
#                      PIB  Valeur_ajoutee_agriculture
# Zone
# Afghanistan    -0.235154                   -0.230323
# Afrique du Sud -0.012689                   -0.116732
# Albanie        -0.238766                   -0.293755
# Algérie        -0.142223                    0.147976
# Allemagne       2.021702                    0.436424

# %%
n_comp=3
fa = FactorAnalyzer(rotation = 'varimax',impute = "drop",n_factors=n_comp)
coord=fa.fit_transform(Z)

results=pd.DataFrame(fa.get_communalities(),columns=['communalities'])
results=results.join(pd.DataFrame(fa.loadings_))
results['components']=results.index+1
results['eigen_values']=fa.get_eigenvalues()[0]
results['variance_%']=list(fa.get_factor_variance()[1])+[None]*(results.shape[0]-n_comp)
results['cumulative_variance_%']=list(fa.get_factor_variance()[2])+[None]*(results.shape[0]-n_comp)

results.index=Z.columns
results
# Out:
#                               communalities         0         1         2  \
# Disponibilite_autres_viandes       0.976170  0.978213  0.136909  0.022942
# Disponibilite_cereales             0.974799  0.069908  0.550539  0.816590
# Disponibilite_volaille             0.956228  0.941370  0.249827 -0.087385
# Exportations_autres_viandes        0.695964  0.787819  0.080925  0.262216
# Exportations_cereales              0.442289  0.491895  0.005010  0.447553
# Exportations_volaille              0.703033  0.838303  0.009544  0.013794
# Importations_autres_viandes        0.463707  0.656811 -0.052074  0.172031
# Importations_cereales              0.535123  0.685659 -0.089219  0.238820
# Nourriture_autres_viandes          0.976358  0.981658  0.110741  0.021000
# Nourriture_cereales                0.884741 -0.060929  0.821166  0.454660
# Nourriture_volaille                0.952157  0.948018  0.214007 -0.087296
# Pertes_autres_viandes              0.714272  0.069277  0.823023  0.179181
# Pertes_cereales                    0.745397  0.004080  0.497166  0.705838
# Pertes_volaille                    0.791529  0.015602  0.882031  0.115356
# Production_autres_viandes          0.978973  0.976376  0.151368  0.052440
# Production_cereales                0.985016  0.070019  0.558924  0.817139
# Production_volaille                0.931270  0.940448  0.204535 -0.070661
# Population                         0.963194  0.256966  0.929062  0.184407
# PIB                                0.822004  0.898660  0.111318  0.044978
# Valeur_ajoutee_agriculture         0.938537  0.400375  0.868556  0.154426
#
#                               components  eigen_values  variance_%  \
# Disponibilite_autres_viandes           1     10.188918    0.453130
# Disponibilite_cereales                 2      5.273567    0.242178
# Disponibilite_volaille                 3      1.478849    0.126230
# Exportations_autres_viandes            4      0.998392         NaN
# Exportations_cereales                  5      0.643096         NaN
# Exportations_volaille                  6      0.449341         NaN
# Importations_autres_viandes            7      0.220878         NaN
# Importations_cereales                  8      0.202592         NaN
# Nourriture_autres_viandes              9      0.162579         NaN
# Nourriture_cereales                   10      0.124015         NaN
# Nourriture_volaille                   11      0.100588         NaN
# Pertes_autres_viandes                 12      0.071046         NaN
# Pertes_cereales                       13      0.040421         NaN
# Pertes_volaille                       14      0.032063         NaN
# Production_autres_viandes             15      0.010734         NaN
# Production_cereales                   16      0.002234         NaN
# Production_volaille                   17      0.000290         NaN
# Population                            18      0.000221         NaN
# PIB                                   19      0.000124         NaN
# Valeur_ajoutee_agriculture            20      0.000053         NaN
#
#                               cumulative_variance_%
# Disponibilite_autres_viandes               0.453130
# Disponibilite_cereales                     0.695308
# Disponibilite_volaille                     0.821538
# Exportations_autres_viandes                     NaN
# Exportations_cereales                           NaN
# Exportations_volaille                           NaN
# Importations_autres_viandes                     NaN
# Importations_cereales                           NaN
# Nourriture_autres_viandes                       NaN
# Nourriture_cereales                             NaN
# Nourriture_volaille                             NaN
# Pertes_autres_viandes                           NaN
# Pertes_cereales                                 NaN
# Pertes_volaille                                 NaN
# Production_autres_viandes                       NaN
# Production_cereales                             NaN
# Production_volaille                             NaN
# Population                                      NaN
# PIB                                             NaN
# Valeur_ajoutee_agriculture                      NaN

# %% [markdown]
# ### les communalities sont toutes superieure 0,30 et sont expliques toute a plus de 30% par l'ACP
#
# les valeurs propre, on applicant cette regle on garde que 3 facteurs soit les 3 premmiers facteurs superieur a 1
#
# les 3 facteurs expliquent 82% de la variance de toutes les variables(45-24-12%)

# %% [markdown]
# #le facteur 0 developpement general
# #facteur 1 developpement agricole
# #facteur2 autosuffisance cereales

# %%
p=Z.shape[1]
n=Z.shape[0]

# %%
plt.scatter(range(1,p+1),results.eigen_values)
plt.plot(range(1,p+1),results.eigen_values)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigen Value')
plt.xticks(np.arange(0, p+1, step=1))
plt.grid()

# %%
df_pca=pd.DataFrame(coord)
columns=['developpement_general','developpement_agricol','autosuffisance_cereales']
df_pca.columns=columns
df_pca.index=Z.index
df_pca.head()
# Out:
#                 developpement_general  developpement_agricol  \
# Zone
# Afghanistan                 -0.286862               0.129745
# Afrique du Sud               0.305010               0.350609
# Albanie                     -0.288225              -0.313761
# Algérie                     -0.153859               0.019802
# Allemagne                    2.631219              -1.781391
#
#                 autosuffisance_cereales
# Zone
# Afghanistan                   -0.346696
# Afrique du Sud                -1.094562
# Albanie                       -0.030440
# Algérie                       -0.243626
# Allemagne                      5.348446

# %%
plan=(0,1)
s=15
fig, axes = plt.subplots(figsize=(12,12))
axes.set_xlim(-s,s) #même limites en abscisse
axes.set_ylim(-s,s) #et en ordonnée
#placement des étiquettes des observations
for i in range(n):
    plt.annotate(df_pca.index[i],(df_pca[df_pca.columns[plan[0]]][i],df_pca[df_pca.columns[plan[1]]][i]))
plt.xlabel(df_pca.columns[plan[0]])
plt.ylabel(df_pca.columns[plan[1]])
#ajouter les axes
plt.plot([-s,s],[0,0],color='silver',linestyle='-',linewidth=1)
plt.plot([0,0],[-s,s],color='silver',linestyle='-',linewidth=1)
#affichage
plt.show()

# %%
## l'Inde Chine et USA -> pays aberrant il faudra le traiter a part

# %%
plan=(0,2)
fig, axes = plt.subplots(figsize=(12,12))
s=6
axes.set_xlim(-s,s) #même limites en abscisse
axes.set_ylim(-s,s) #et en ordonnée
#placement des étiquettes des observations
for i in range(n):
    plt.annotate(df_pca.index[i],(df_pca[df_pca.columns[plan[0]]][i],df_pca[df_pca.columns[plan[1]]][i]))
plt.xlabel(df_pca.columns[plan[0]])
plt.ylabel(df_pca.columns[plan[1]])
#ajouter les axes
plt.plot([-s,s],[0,0],color='silver',linestyle='-',linewidth=1)
plt.plot([0,0],[-s,s],color='silver',linestyle='-',linewidth=1)
#affichage
plt.show()

# %%
# bresil comme pays aberrant

# %%
plan=(1,2)
fig, axes = plt.subplots(figsize=(12,12))
axes.set_xlim(-6,6) #même limites en abscisse
axes.set_ylim(-6,6) #et en ordonnée
#placement des étiquettes des observations
for i in range(n):
    plt.annotate(df_pca.index[i],(df_pca[df_pca.columns[plan[0]]][i],df_pca[df_pca.columns[plan[1]]][i]))
plt.xlabel(df_pca.columns[plan[0]])
plt.ylabel(df_pca.columns[plan[1]])
#ajouter les axes
plt.plot([-6,6],[0,0],color='silver',linestyle='-',linewidth=1)
plt.plot([0,0],[-6,6],color='silver',linestyle='-',linewidth=1)
#affichage
plt.show()

# %% [markdown]
# # clusterings

# %% [markdown]
# https://towardsdatascience.com/clustering-algorithms-for-customer-segmentation-af637c6830ac

# %%
X=df_pca
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    km=KMeans(n_clusters=i,init='k-means++', max_iter=300, n_init=10, random_state=0)
    km.fit(X)
    wcss.append(km.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.xticks(range(1,11))
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
km4=KMeans(n_clusters=4,init='k-means++', max_iter=300, n_init=10, random_state=0)
y_means = km4.fit_predict(X)
X['clusters']=y_means
X.head(10)
# Out:
#                     developpement_general  developpement_agricol  \
# Zone
# Afghanistan                     -0.286862               0.129745
# Afrique du Sud                   0.305010               0.350609
# Albanie                         -0.288225              -0.313761
# Algérie                         -0.153859               0.019802
# Allemagne                        2.631219              -1.781391
# Angola                          -0.215311              -0.323830
# Antigua-et-Barbuda              -0.324450              -0.290987
# Arabie saoudite                 -0.069587              -0.386315
# Argentine                        0.874919              -0.174866
# Arménie                         -0.292315              -0.162479
#
#                     autosuffisance_cereales  clusters
# Zone
# Afghanistan                       -0.346696         0
# Afrique du Sud                    -1.094562         0
# Albanie                           -0.030440         0
# Algérie                           -0.243626         0
# Allemagne                          5.348446         1
# Angola                             0.296607         0
# Antigua-et-Barbuda                -0.029671         0
# Arabie saoudite                   -0.021540         0
# Argentine                          1.191274         0
# Arménie                           -0.208258         0

# %%
plan=(0,1)
plt.scatter(X[y_means==0][X.columns[plan[0]]],X[y_means==0][X.columns[plan[1]]],s=50, c='purple',label='Cluster1')
plt.scatter(X[y_means==1][X.columns[plan[0]]],X[y_means==1][X.columns[plan[1]]],s=50, c='blue',label='Cluster2')
plt.scatter(X[y_means==2][X.columns[plan[0]]],X[y_means==2][X.columns[plan[1]]],s=50, c='green',label='Cluster3')
plt.scatter(X[y_means==3][X.columns[plan[0]]],X[y_means==3][X.columns[plan[1]]],s=50, c='cyan',label='Cluster4')
plt.scatter(km4.cluster_centers_[:,0], km4.cluster_centers_[:,1],s=200,marker='s', c='red', alpha=0.7, label='Centroids')
plt.title('perceptual map')
plt.xlabel(X.columns[plan[0]])
plt.ylabel(X.columns[plan[1]])
plt.legend()
plt.show()

# %%
plan=(1,2)
plt.scatter(X[y_means==0][X.columns[plan[0]]],X[y_means==0][X.columns[plan[1]]],s=50, c='purple',label='Cluster1')
plt.scatter(X[y_means==1][X.columns[plan[0]]],X[y_means==1][X.columns[plan[1]]],s=50, c='blue',label='Cluster2')
plt.scatter(X[y_means==2][X.columns[plan[0]]],X[y_means==2][X.columns[plan[1]]],s=50, c='green',label='Cluster3')
plt.scatter(X[y_means==3][X.columns[plan[0]]],X[y_means==3][X.columns[plan[1]]],s=50, c='cyan',label='Cluster4')
plt.scatter(km4.cluster_centers_[:,0], km4.cluster_centers_[:,1],s=200,marker='s', c='red', alpha=0.7, label='Centroids')
plt.title('perceptual map')
plt.xlabel(X.columns[plan[0]])
plt.ylabel(X.columns[plan[1]])
plt.legend()
plt.show()

# %%
plan=(0,2)
plt.scatter(X[y_means==0][X.columns[plan[0]]],X[y_means==0][X.columns[plan[1]]],s=50, c='purple',label='Cluster1')
plt.scatter(X[y_means==1][X.columns[plan[0]]],X[y_means==1][X.columns[plan[1]]],s=50, c='blue',label='Cluster2')
plt.scatter(X[y_means==2][X.columns[plan[0]]],X[y_means==2][X.columns[plan[1]]],s=50, c='green',label='Cluster3')
plt.scatter(X[y_means==3][X.columns[plan[0]]],X[y_means==3][X.columns[plan[1]]],s=50, c='cyan',label='Cluster4')
plt.scatter(km4.cluster_centers_[:,0], km4.cluster_centers_[:,1],s=200,marker='s', c='red', alpha=0.7, label='Centroids')
plt.title('perceptual map')
plt.xlabel(X.columns[plan[0]])
plt.ylabel(X.columns[plan[1]])
plt.legend()
plt.show()

# %%
clust=X.groupby('clusters').agg(np.mean)
clust
# Out:
#           developpement_general  developpement_agricol  \
# clusters
# 0                     -0.078241              -0.051907
# 1                      0.953371              -1.057452
# 2                     -0.575293              11.365775
# 3                     10.311912               0.163682
#
#           autosuffisance_cereales
# clusters
# 0                       -0.136412
# 1                        6.461935
# 2                        3.298830
# 3                       -0.722362

# %%
plan=(0,1)
plt.scatter(clust[X.columns[plan[0]]][0],clust[X.columns[plan[1]]][0],s=50, marker='s', c='purple',label='Cluster1')
plt.scatter(clust[X.columns[plan[0]]][1],clust[X.columns[plan[1]]][1],s=50, marker='d', c='blue',label='Cluster2')
plt.scatter(clust[X.columns[plan[0]]][2],clust[X.columns[plan[1]]][2],s=50,marker='o', c='green',label='Cluster3')
plt.scatter(clust[X.columns[plan[0]]][3],clust[X.columns[plan[1]]][3],s=50,marker='p', c='red',label='Cluster4')
plt.title('perceptual map')
plt.xlabel(X.columns[plan[0]])
plt.ylabel(X.columns[plan[1]])
plt.legend()
plt.show()

# %%
plan=(0,2)
plt.scatter(clust[X.columns[plan[0]]][0],clust[X.columns[plan[1]]][0],s=50, marker='s', c='purple',label='Cluster1')
plt.scatter(clust[X.columns[plan[0]]][1],clust[X.columns[plan[1]]][1],s=50, marker='d', c='blue',label='Cluster2')
plt.scatter(clust[X.columns[plan[0]]][2],clust[X.columns[plan[1]]][2],s=50,marker='o', c='green',label='Cluster3')
plt.scatter(clust[X.columns[plan[0]]][3],clust[X.columns[plan[1]]][3],s=50,marker='p', c='red',label='Cluster4')
plt.title('perceptual map')
plt.xlabel(X.columns[plan[0]])
plt.ylabel(X.columns[plan[1]])
plt.legend()
plt.show()

# %%
plan=(1,2)
plt.scatter(clust[X.columns[plan[0]]][0],clust[X.columns[plan[1]]][0],s=50, marker='s', c='purple',label='Cluster1')
plt.scatter(clust[X.columns[plan[0]]][1],clust[X.columns[plan[1]]][1],s=50, marker='d', c='blue',label='Cluster2')
plt.scatter(clust[X.columns[plan[0]]][2],clust[X.columns[plan[1]]][2],s=50,marker='o', c='green',label='Cluster3')
plt.scatter(clust[X.columns[plan[0]]][3],clust[X.columns[plan[1]]][3],s=50,marker='p', c='red',label='Cluster4')
plt.title('perceptual map')
plt.xlabel(X.columns[plan[0]])
plt.ylabel(X.columns[plan[1]])
plt.legend()
plt.show()

# %%
pour le cluster 3 , fort developpement agricole , autosuffisance creales moyenne et developpement generale faible
>>>
>>>
>>>

# %%
X[X.clusters==0]
# Out:
#                      developpement_general  developpement_agricol  \
# Zone
# Afghanistan                      -0.286862               0.129745
# Afrique du Sud                    0.305010               0.350609
# Albanie                          -0.288225              -0.313761
# Algérie                          -0.153859               0.019802
# Angola                           -0.215311              -0.323830
# ...                                    ...                    ...
# Zimbabwe                         -0.291476              -0.044628
# Égypte                            0.117271               0.838338
# Émirats arabes unis              -0.229342               0.026529
# Équateur                         -0.139881              -0.186018
# Îles Salomon                     -0.322510              -0.302606
#
#                      autosuffisance_cereales  clusters
# Zone
# Afghanistan                        -0.346696         0
# Afrique du Sud                     -1.094562         0
# Albanie                            -0.030440         0
# Algérie                            -0.243626         0
# Angola                              0.296607         0
# ...                                      ...       ...
# Zimbabwe                           -0.295797         0
# Égypte                             -1.201674         0
# Émirats arabes unis                -0.327771         0
# Équateur                           -0.144447         0
# Îles Salomon                       -0.026344         0
#
# [161 rows x 4 columns]

# %%
X[X.clusters==1]
# Out:
#            developpement_general  developpement_agricol  \
# Zone
# Allemagne               2.631219              -1.781391
# Pologne                 0.852502              -2.096605
# Éthiopie               -0.623607               0.705640
#
#            autosuffisance_cereales  clusters
# Zone
# Allemagne                 5.348446         1
# Pologne                   8.343991         1
# Éthiopie                  5.693367         1

# %%
X[X.clusters==2]
# Out:
#       developpement_general  developpement_agricol  autosuffisance_cereales  \
# Zone
# Inde              -0.575293              11.365775                  3.29883
#
#       clusters
# Zone
# Inde         2

# %%
X[X.clusters==3]
# Out:
#                        developpement_general  developpement_agricol  \
# Zone
# États-Unis d'Amérique              10.311912               0.163682
#
#                        autosuffisance_cereales  clusters
# Zone
# États-Unis d'Amérique                -0.722362         3
